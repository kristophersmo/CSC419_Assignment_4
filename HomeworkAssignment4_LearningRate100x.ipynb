# %%
# CSC 419 Homework Assignment 4
# Introduction to Neural Networks
# Base Program

# Code run/edit by Kristopher Smolarek (F00568254)
# Submitted June 5, 2024

import numpy as np  # to load data set
import torch  # to build the neural network
import torch.nn as nn
import torch.optim as optim

# %%
# Load .csv ataset
dataset = np.loadtxt('pima_indians_diabetes.csv', delimiter=',')

# Split into input (X) and output (y) variables
X = dataset[:,0:8]
y = dataset[:,8]

# %%
# Convert data set to PyTorch tensors
X = torch.tensor(X, dtype=torch.float32)
y = torch.tensor(y, dtype=torch.float32).reshape(-1, 1)

# %%
# Defining the neural network model
model = nn.Sequential(
    nn.Linear(8, 12),
    nn.ReLU(),
    nn.Linear(12, 8),
    nn.ReLU(),
    nn.Linear(8, 1),
    nn.Sigmoid())

print(model)
# Out:
# Sequential(
#   (0): Linear(in_features=8, out_features=12, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=12, out_features=8, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=8, out_features=1, bias=True)
#   (5): Sigmoid()
# )

# %%
# Setting the loss function and optimizer
loss_fn = nn.BCELoss()  # binary cross entropy
optimizer = optim.Adam(model.parameters(), lr=0.1)

# %%
# Training the neural network model
n_epochs = 100
batch_size = 10

for epoch in range(n_epochs):
    for i in range(0, len(X), batch_size):
        Xbatch = X[i:i+batch_size]
        y_pred = model(Xbatch)
        ybatch = y[i:i+batch_size]
        loss = loss_fn(y_pred, ybatch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Finished epoch {epoch}, latest loss {loss}')
# Out:
# Finished epoch 0, latest loss 0.5693978667259216
# Finished epoch 1, latest loss 0.5696060061454773
# Finished epoch 2, latest loss 0.5700194239616394
# Finished epoch 3, latest loss 0.5702129602432251
# Finished epoch 4, latest loss 0.5703296661376953
# Finished epoch 5, latest loss 0.5704073309898376
# Finished epoch 6, latest loss 0.5704625844955444
# Finished epoch 7, latest loss 0.5705037713050842
# Finished epoch 8, latest loss 0.5705352425575256
# Finished epoch 9, latest loss 0.5705602765083313
# Finished epoch 10, latest loss 0.5705804228782654
# Finished epoch 11, latest loss 0.5705969929695129
# Finished epoch 12, latest loss 0.5706107020378113
# Finished epoch 13, latest loss 0.5706222653388977
# Finished epoch 14, latest loss 0.5706321597099304
# Finished epoch 15, latest loss 0.5706405639648438
# Finished epoch 16, latest loss 0.5706478357315063
# Finished epoch 17, latest loss 0.5706541538238525
# Finished epoch 18, latest loss 0.5706597566604614
# Finished epoch 19, latest loss 0.570664644241333
# Finished epoch 20, latest loss 0.5706689357757568
# Finished epoch 21, latest loss 0.5706728100776672
# Finished epoch 22, latest loss 0.5706762075424194
# Finished epoch 23, latest loss 0.5706791877746582
# Finished epoch 24, latest loss 0.5706818699836731
# Finished epoch 25, latest loss 0.5706843137741089
# Finished epoch 26, latest loss 0.5706865191459656
# Finished epoch 27, latest loss 0.5706884860992432
# Finished epoch 28, latest loss 0.5706902146339417
# Finished epoch 29, latest loss 0.5706918835639954
# Finished epoch 30, latest loss 0.57069331407547
# Finished epoch 31, latest loss 0.5706945657730103
# Finished epoch 32, latest loss 0.5706958174705505
# Finished epoch 33, latest loss 0.5706968307495117
# Finished epoch 34, latest loss 0.5706978440284729
# Finished epoch 35, latest loss 0.5706987977027893
# Finished epoch 36, latest loss 0.5706995725631714
# Finished epoch 37, latest loss 0.5707003474235535
# Finished epoch 38, latest loss 0.5707010626792908
# Finished epoch 39, latest loss 0.5707016587257385
# Finished epoch 40, latest loss 0.5707021951675415
# Finished epoch 41, latest loss 0.5707027316093445
# Finished epoch 42, latest loss 0.5707032084465027
# Finished epoch 43, latest loss 0.5707036256790161
# Finished epoch 44, latest loss 0.5707040429115295
# Finished epoch 45, latest loss 0.5707044005393982
# Finished epoch 46, latest loss 0.5707047581672668
# Finished epoch 47, latest loss 0.5707050561904907
# Finished epoch 48, latest loss 0.5707053542137146
# Finished epoch 49, latest loss 0.5707056522369385
# Finished epoch 50, latest loss 0.5707058310508728
# Finished epoch 51, latest loss 0.5707060694694519
# Finished epoch 52, latest loss 0.5707062482833862
# Finished epoch 53, latest loss 0.5707064270973206
# Finished epoch 54, latest loss 0.5707065463066101
# Finished epoch 55, latest loss 0.5707067847251892
# Finished epoch 56, latest loss 0.5707069039344788
# Finished epoch 57, latest loss 0.5707070827484131
# Finished epoch 58, latest loss 0.5707071423530579
# Finished epoch 59, latest loss 0.5707073211669922
# Finished epoch 60, latest loss 0.5707074403762817
# Finished epoch 61, latest loss 0.5707074403762817
# Finished epoch 62, latest loss 0.5707075595855713
# Finished epoch 63, latest loss 0.5707076787948608
# Finished epoch 64, latest loss 0.5707076191902161
# Finished epoch 65, latest loss 0.5707077980041504
# Finished epoch 66, latest loss 0.5707078576087952
# Finished epoch 67, latest loss 0.5707079172134399
# Finished epoch 68, latest loss 0.5707079768180847
# Finished epoch 69, latest loss 0.5707079768180847
# Finished epoch 70, latest loss 0.5707080364227295
# Finished epoch 71, latest loss 0.5707079768180847
# Finished epoch 72, latest loss 0.5707080960273743
# Finished epoch 73, latest loss 0.570708155632019
# Finished epoch 74, latest loss 0.570708155632019
# Finished epoch 75, latest loss 0.5707082152366638
# Finished epoch 76, latest loss 0.5707082748413086
# Finished epoch 77, latest loss 0.5707082152366638
# Finished epoch 78, latest loss 0.5707082748413086
# Finished epoch 79, latest loss 0.5707082748413086
# Finished epoch 80, latest loss 0.5707083344459534
# Finished epoch 81, latest loss 0.5707083344459534
# Finished epoch 82, latest loss 0.5707083344459534
# Finished epoch 83, latest loss 0.5707083940505981
# Finished epoch 84, latest loss 0.5707083940505981
# Finished epoch 85, latest loss 0.5707084536552429
# Finished epoch 86, latest loss 0.5707083940505981
# Finished epoch 87, latest loss 0.5707083940505981
# Finished epoch 88, latest loss 0.5707083940505981
# Finished epoch 89, latest loss 0.5707083940505981
# Finished epoch 90, latest loss 0.5707084536552429
# Finished epoch 91, latest loss 0.5707084536552429
# Finished epoch 92, latest loss 0.5707085132598877
# Finished epoch 93, latest loss 0.5707085132598877
# Finished epoch 94, latest loss 0.5707085132598877
# Finished epoch 95, latest loss 0.5707085132598877
# Finished epoch 96, latest loss 0.5707085132598877
# Finished epoch 97, latest loss 0.5707085132598877
# Finished epoch 98, latest loss 0.5707085132598877
# Finished epoch 99, latest loss 0.5707085132598877

# %%
# Model Evaluation (determining accuracy)
with torch.no_grad():
    y_pred = model(X)

accuracy = (y_pred.round() == y).float().mean()
print(f"Accuracy {accuracy}")
# Out:
# Accuracy 0.6510416865348816
