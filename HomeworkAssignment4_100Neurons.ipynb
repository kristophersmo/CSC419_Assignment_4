# %%
# CSC 419 Homework Assignment 4
# Introduction to Neural Networks
# Hidden Layer Containing 100 Neurons

# Code run/edit by Kristopher Smolarek (F00568254)
# Submitted June 5, 2024

import numpy as np  # to load data set
import torch  # to build the neural network
import torch.nn as nn
import torch.optim as optim

# %%
# Load .csv ataset
dataset = np.loadtxt('pima_indians_diabetes.csv', delimiter=',')

# Split into input (X) and output (y) variables
X = dataset[:,0:8]
y = dataset[:,8]

# %%
# Convert data set to PyTorch tensors
X = torch.tensor(X, dtype=torch.float32)
y = torch.tensor(y, dtype=torch.float32).reshape(-1, 1)

# %%
# Defining the neural network model
model = nn.Sequential(
    nn.Linear(8, 100),
    nn.ReLU(),
    nn.Linear(100, 100),
    nn.ReLU(),
    nn.Linear(100, 100),
    nn.ReLU(),
    nn.Linear(100, 1),
    nn.Sigmoid())

print(model)
# Out:
# Sequential(
#   (0): Linear(in_features=8, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=100, out_features=1, bias=True)
#   (7): Sigmoid()
# )

# %%
# Setting the loss function and optimizer
loss_fn = nn.BCELoss()  # binary cross entropy
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# Training the neural network model
n_epochs = 100
batch_size = 10

for epoch in range(n_epochs):
    for i in range(0, len(X), batch_size):
        Xbatch = X[i:i+batch_size]
        y_pred = model(Xbatch)
        ybatch = y[i:i+batch_size]
        loss = loss_fn(y_pred, ybatch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Finished epoch {epoch}, latest loss {loss}')
# Out:
# Finished epoch 0, latest loss 0.549267053604126
# Finished epoch 1, latest loss 0.49516361951828003
# Finished epoch 2, latest loss 0.46484676003456116
# Finished epoch 3, latest loss 0.4524330794811249
# Finished epoch 4, latest loss 0.47496846318244934
# Finished epoch 5, latest loss 0.44344812631607056
# Finished epoch 6, latest loss 0.4337049126625061
# Finished epoch 7, latest loss 0.4406796991825104
# Finished epoch 8, latest loss 0.43617475032806396
# Finished epoch 9, latest loss 0.42472419142723083
# Finished epoch 10, latest loss 0.4184340834617615
# Finished epoch 11, latest loss 0.4289981424808502
# Finished epoch 12, latest loss 0.4221593737602234
# Finished epoch 13, latest loss 0.4030371308326721
# Finished epoch 14, latest loss 0.4090556204319
# Finished epoch 15, latest loss 0.40564483404159546
# Finished epoch 16, latest loss 0.4403682351112366
# Finished epoch 17, latest loss 0.4045124650001526
# Finished epoch 18, latest loss 0.39144623279571533
# ...

# %%
# Model Evaluation (determining accuracy)
with torch.no_grad():
    y_pred = model(X)

accuracy = (y_pred.round() == y).float().mean()
print(f"Accuracy {accuracy}")
# Out:
# Accuracy 0.8450520634651184
