# %%
# CSC 419 Homework Assignment 4
# Introduction to Neural Networks
# Epochs = 200

# Code run/edit by Kristopher Smolarek (F00568254)
# Submitted June 5, 2024

import numpy as np  # to load data set
import torch  # to build the neural network
import torch.nn as nn
import torch.optim as optim

# %%
# Load .csv ataset
dataset = np.loadtxt('pima_indians_diabetes.csv', delimiter=',')

# Split into input (X) and output (y) variables
X = dataset[:,0:8]
y = dataset[:,8]

# %%
# Convert data set to PyTorch tensors
X = torch.tensor(X, dtype=torch.float32)
y = torch.tensor(y, dtype=torch.float32).reshape(-1, 1)

# %%
# Defining the neural network model
model = nn.Sequential(
    nn.Linear(8, 12),
    nn.ReLU(),
    nn.Linear(12, 8),
    nn.ReLU(),
    nn.Linear(8, 1),
    nn.Sigmoid())

print(model)
# Out:
# Sequential(
#   (0): Linear(in_features=8, out_features=12, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=12, out_features=8, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=8, out_features=1, bias=True)
#   (5): Sigmoid()
# )

# %%
# Setting the loss function and optimizer
loss_fn = nn.BCELoss()  # binary cross entropy
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# Training the neural network model
n_epochs = 200
batch_size = 10

for epoch in range(n_epochs):
    for i in range(0, len(X), batch_size):
        Xbatch = X[i:i+batch_size]
        y_pred = model(Xbatch)
        ybatch = y[i:i+batch_size]
        loss = loss_fn(y_pred, ybatch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Finished epoch {epoch}, latest loss {loss}')
# Out:
# Finished epoch 0, latest loss 0.6123936176300049
# Finished epoch 1, latest loss 0.5545448660850525
# Finished epoch 2, latest loss 0.5289492011070251
# Finished epoch 3, latest loss 0.5013467073440552
# Finished epoch 4, latest loss 0.46447354555130005
# Finished epoch 5, latest loss 0.44467100501060486
# Finished epoch 6, latest loss 0.4379524886608124
# Finished epoch 7, latest loss 0.44054874777793884
# Finished epoch 8, latest loss 0.43955883383750916
# Finished epoch 9, latest loss 0.4345139265060425
# Finished epoch 10, latest loss 0.43019750714302063
# Finished epoch 11, latest loss 0.4273355305194855
# Finished epoch 12, latest loss 0.42436468601226807
# Finished epoch 13, latest loss 0.4259644150733948
# Finished epoch 14, latest loss 0.4276620149612427
# Finished epoch 15, latest loss 0.4250580668449402
# Finished epoch 16, latest loss 0.42386072874069214
# Finished epoch 17, latest loss 0.41910839080810547
# Finished epoch 18, latest loss 0.42143934965133667
# Finished epoch 19, latest loss 0.42312154173851013
# Finished epoch 20, latest loss 0.417377769947052
# Finished epoch 21, latest loss 0.4172423481941223
# Finished epoch 22, latest loss 0.41113442182540894
# Finished epoch 23, latest loss 0.39965876936912537
# Finished epoch 24, latest loss 0.4021608531475067
# Finished epoch 25, latest loss 0.4011150300502777
# Finished epoch 26, latest loss 0.4036242365837097
# Finished epoch 27, latest loss 0.40089210867881775
# Finished epoch 28, latest loss 0.39715635776519775
# Finished epoch 29, latest loss 0.3946068584918976
# Finished epoch 30, latest loss 0.39144665002822876
# Finished epoch 31, latest loss 0.388107568025589
# Finished epoch 32, latest loss 0.38320693373680115
# Finished epoch 33, latest loss 0.3828033208847046
# Finished epoch 34, latest loss 0.3752562999725342
# Finished epoch 148, latest loss 0.23430576920509338
# Finished epoch 149, latest loss 0.2377251535654068
# Finished epoch 150, latest loss 0.23390212655067444
# Finished epoch 151, latest loss 0.22655218839645386
# Finished epoch 152, latest loss 0.230033278465271
# Finished epoch 153, latest loss 0.2280513495206833
# Finished epoch 154, latest loss 0.2278079092502594
# Finished epoch 155, latest loss 0.2268419712781906
# Finished epoch 156, latest loss 0.2206948697566986
# Finished epoch 157, latest loss 0.22803983092308044
# Finished epoch 158, latest loss 0.22704559564590454
# Finished epoch 159, latest loss 0.21778565645217896
# Finished epoch 160, latest loss 0.23172985017299652
# Finished epoch 161, latest loss 0.22578272223472595
# Finished epoch 162, latest loss 0.2223057746887207
# Finished epoch 163, latest loss 0.2223394513130188
# Finished epoch 164, latest loss 0.22414784133434296
# Finished epoch 165, latest loss 0.22424404323101044
# Finished epoch 166, latest loss 0.2236410528421402
# Finished epoch 167, latest loss 0.22169256210327148
# Finished epoch 168, latest loss 0.22543027997016907
# Finished epoch 169, latest loss 0.22323621809482574
# Finished epoch 170, latest loss 0.22443538904190063
# Finished epoch 171, latest loss 0.22167479991912842
# Finished epoch 172, latest loss 0.22348108887672424
# Finished epoch 173, latest loss 0.22914941608905792
# Finished epoch 174, latest loss 0.22225067019462585
# Finished epoch 175, latest loss 0.2270601987838745
# Finished epoch 176, latest loss 0.226248636841774
# Finished epoch 177, latest loss 0.2235906422138214
# Finished epoch 178, latest loss 0.22853268682956696
# Finished epoch 179, latest loss 0.2229684591293335
# Finished epoch 180, latest loss 0.2190917730331421
# Finished epoch 181, latest loss 0.23000532388687134
# Finished epoch 182, latest loss 0.22105327248573303
# Finished epoch 183, latest loss 0.22270101308822632
# Finished epoch 184, latest loss 0.22345469892024994
# Finished epoch 185, latest loss 0.22888223826885223
# Finished epoch 186, latest loss 0.22208836674690247
# Finished epoch 187, latest loss 0.21232445538043976
# Finished epoch 188, latest loss 0.22706115245819092
# Finished epoch 189, latest loss 0.21908541023731232
# Finished epoch 190, latest loss 0.22042231261730194
# Finished epoch 191, latest loss 0.22412055730819702
# Finished epoch 192, latest loss 0.22105249762535095
# Finished epoch 193, latest loss 0.21613316237926483
# Finished epoch 194, latest loss 0.21760237216949463
# Finished epoch 195, latest loss 0.2174958884716034
# Finished epoch 196, latest loss 0.22502779960632324
# Finished epoch 197, latest loss 0.2158881425857544
# Finished epoch 198, latest loss 0.21475374698638916
# Finished epoch 199, latest loss 0.21685141324996948

# %%
# Model Evaluation (determining accuracy)
with torch.no_grad():
    y_pred = model(X)

accuracy = (y_pred.round() == y).float().mean()
print(f"Accuracy {accuracy}")
# Out:
# Accuracy 0.7591145634651184
